# %% [markdown]
# https://www.kaggle.com/datasets/rashikrahmanpritom/heart-attack-analysis-prediction-dataset Heart Attack Analysis and Prediction Dataset. Goal: create a model that predicts if patients are at risk of heart attacks from characteristics of the individual such as if it smokes, sex, blood pressure, etc

# %%
pip install pandas numpy matplotlib seaborn scikit-learn tensorflow keras-tuner ipywidgets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (2.2.2)
# Requirement already satisfied: numpy in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (1.26.4)
# Requirement already satisfied: matplotlib in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (3.9.2)
# Requirement already satisfied: seaborn in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (1.5.2)
# Requirement already satisfied: tensorflow in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (2.16.1)
# Requirement already satisfied: keras-tuner in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (1.4.7)
# Requirement already satisfied: ipywidgets in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (8.1.5)
# Requirement already satisfied: pytz>=2020.1 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from pandas) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: cycler>=0.10 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from matplotlib) (6.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: pillow>=8 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: scipy>=1.6.0 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from tensorflow) (0.3.2)
# Requirement already satisfied: h5py>=3.10.0 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from tensorflow) (4.25.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from tensorflow) (0.37.0)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.16.2)
# Requirement already satisfied: libclang>=13.0.0 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: keras>=3.0.0 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from tensorflow) (3.3.3)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: six>=1.12.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: setuptools in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow) (58.0.4)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: kt-legacy in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: comm>=0.1.3 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from ipywidgets) (8.18.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.19.2)
# Requirement already satisfied: pygments>=2.4.0 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: decorator in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: pexpect>4.3 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: matplotlib-inline in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.48)
# Requirement already satisfied: stack-data in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: jedi>=0.16 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: exceptiongroup in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (1.2.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: optree in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from keras>=3.0.0->tensorflow) (0.11.0)
# Requirement already satisfied: rich in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from keras>=3.0.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from keras>=3.0.0->tensorflow) (0.0.8)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.6.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: markdown>=2.6.8 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.0.3)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from markdown>=2.6.8->tensorboard<2.17,>=2.16->tensorflow) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from rich->keras>=3.0.0->tensorflow) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow) (0.1.2)
# Requirement already satisfied: pure-eval in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: executing>=1.2.0 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/lionelweng/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# Data Manipulation and Visualization
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Scikit-Learn Modules
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier

# TensorFlow and Keras Modules
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping

# Keras Tuner
import keras_tuner as kt

# Jupyter Notebook Widgets
import ipywidgets as widgets
from IPython.display import display, clear_output

import tensorflow as tf


# Optional: Checking TensorFlow and Keras Tuner Versions for Compatibility
print("TensorFlow version:", tf.__version__)
print("Keras Tuner version:", kt.__version__)
# Out:
# TensorFlow version: 2.16.1
# Keras Tuner version: 1.4.7

# %% [markdown]
# Importing necessary libraries

# %%
df = pd.read_csv('heart.csv')
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %% [markdown]
# Loading CSV
# And displaying first 5 rows

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %% [markdown]
# Check for missing values

# %%
df.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#             thall      output
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %% [markdown]
# Get basic statistics

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(), annot=True, fmt='.2f')
plt.show()

# %% [markdown]
# Visualize the correlation matrix

# %%
X = df.drop('output', axis=1)
y = df['output']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# Define features and target variable
# Standardize the features

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# Spit into training and testing sets

# %%
model = tf.keras.Sequential([
    layers.Dense(16, activation='relu', input_shape=(X_train.shape[1],)),
    layers.Dense(8, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])
# Out:
# /Users/lionelweng/Library/Python/3.9/lib/python/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Define the model architecture

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=16,
    validation_split=0.1
)
# Out:
# Epoch 1/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4679 - loss: 0.7619 - val_accuracy: 0.5200 - val_loss: 0.7427
# Epoch 2/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5029 - loss: 0.7139 - val_accuracy: 0.5200 - val_loss: 0.6878
# Epoch 3/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5934 - loss: 0.6498 - val_accuracy: 0.5600 - val_loss: 0.6440
# Epoch 4/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6607 - loss: 0.6250 - val_accuracy: 0.6000 - val_loss: 0.6069
# Epoch 5/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7167 - loss: 0.6018 - val_accuracy: 0.6400 - val_loss: 0.5732
# Epoch 6/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7839 - loss: 0.5501 - val_accuracy: 0.8000 - val_loss: 0.5393
# Epoch 7/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7738 - loss: 0.5418 - val_accuracy: 0.8400 - val_loss: 0.5109
# Epoch 8/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8111 - loss: 0.4866 - val_accuracy: 0.8400 - val_loss: 0.4856
# Epoch 9/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7712 - loss: 0.4901 - val_accuracy: 0.8400 - val_loss: 0.4635
# Epoch 10/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8126 - loss: 0.4555 - val_accuracy: 0.8800 - val_loss: 0.4432
# Epoch 11/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8393 - loss: 0.4294 - val_accuracy: 0.8800 - val_loss: 0.4235
# Epoch 12/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8293 - loss: 0.4382 - val_accuracy: 0.8800 - val_loss: 0.4076
# Epoch 13/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8393 - loss: 0.4157 - val_accuracy: 0.8800 - val_loss: 0.3933
# Epoch 14/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8739 - loss: 0.3815 - val_accuracy: 0.8800 - val_loss: 0.3786
# Epoch 15/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8424 - loss: 0.3812 - val_accuracy: 0.8800 - val_loss: 0.3681
# Epoch 16/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.

# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8178 - loss: 0.4757
#
# Test Accuracy: 0.84

# %% [markdown]
# Evaluate on the test set

# %%
plt.figure(figsize=(12,4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# %% [markdown]
# Plot training & validation accuracy values

# %%
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# %%
plt.show()

# %% [markdown]
# Predict probabilities

# %%
y_pred_prob = model.predict(X_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %% [markdown]
# Convert probabilities to class labels

# %%
y_pred = (y_pred_prob > 0.5).astype(int).flatten()

# %% [markdown]
# Classification Report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.86      0.83        29
#            1       0.87      0.81      0.84        32
#
#     accuracy                           0.84        61
#    macro avg       0.84      0.84      0.84        61
# weighted avg       0.84      0.84      0.84        61

# %% [markdown]
# Confusion Matrix

# %%
cm = confusion_matrix(y_test, y_pred)

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.show()

# %%
model.save('heart_attack_model_v1.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
def build_model(hp):
    model = keras.Sequential()

# %% [markdown]
# Tune the number of layers between 1 and 3
# Add dropout to prevent overfitting
# Tune the learning rate

# %%
def build_model(hp):
    model = keras.Sequential()
    
    for i in range(hp.Int('num_layers', 1, 3)):
        model.add(layers.Dense(
            units=hp.Int('units_' + str(i),
                         min_value=8,
                         max_value=64,
                         step=8),
            activation='relu'))
        model.add(layers.Dropout(
            rate=hp.Float('dropout_rate_' + str(i),
                          min_value=0.0,
                          max_value=0.5,
                          step=0.1)))
    
    model.add(layers.Dense(1, activation='sigmoid'))
    
    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])
    
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
        loss='binary_crossentropy',
        metrics=['accuracy'])
    
    return model

# %%
tuner = kt.RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=10,
    executions_per_trial=2,
    directory='kt_dir',
    project_name='heart_attack_prediction')
# Out:
# Reloading Tuner from kt_dir/heart_attack_prediction/tuner0.json

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

tuner.search(X_train, y_train,
             epochs=50,
             validation_split=0.1,
             callbacks=[early_stopping])

# %%
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
The hyperparameter search is complete.
Optimal number of layers: {best_hps.get('num_layers')}
""")

for i in range(best_hps.get('num_layers')):
    print(f"Units in layer {i}: {best_hps.get('units_' + str(i))}")
    print(f"Dropout rate in layer {i}: {best_hps.get('dropout_rate_' + str(i))}")
    
print(f"Optimal learning rate: {best_hps.get('learning_rate')}")
# Out:
# The hyperparameter search is complete.
# Optimal number of layers: 1
#
# Units in layer 0: 56
# Dropout rate in layer 0: 0.4
# Optimal learning rate: 0.01

# %% [markdown]
# Build the best model & train

# %%
model = tuner.hypermodel.build(best_hps)

history = model.fit(X_train, y_train,
                    epochs=100,
                    validation_split=0.1,
                    callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5663 - loss: 0.6800 - val_accuracy: 0.8400 - val_loss: 0.4083
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7416 - loss: 0.4869 - val_accuracy: 0.8400 - val_loss: 0.3533
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8046 - loss: 0.4040 - val_accuracy: 0.8400 - val_loss: 0.3439
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8175 - loss: 0.4045 - val_accuracy: 0.8400 - val_loss: 0.3399
# Epoch 5/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8835 - loss: 0.2884 - val_accuracy: 0.8000 - val_loss: 0.3444
# Epoch 6/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8507 - loss: 0.3404 - val_accuracy: 0.8400 - val_loss: 0.3359
# Epoch 7/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8752 - loss: 0.3165 - val_accuracy: 0.8400 - val_loss: 0.3497
# Epoch 8/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8915 - loss: 0.2971 - val_accuracy: 0.8400 - val_loss: 0.3548
# Epoch 9/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8752 - loss: 0.3230 - val_accuracy: 0.8000 - val_loss: 0.3462
# Epoch 10/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9227 - loss: 0.2676 - val_accuracy: 0.8000 - val_loss: 0.3499
# Epoch 11/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8707 - loss: 0.2905 - val_accuracy: 0.8000 - val_loss: 0.3469

# %% [markdown]
# Plot training & validation accuracy values

# %%
plt.figure(figsize=(12,4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Model Accuracy after Hyperparameter Tuning')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# %% [markdown]
# Plot training & validation loss values

# %%
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Model Loss after Hyperparameter Tuning')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
y_pred_prob = model.predict(X_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
y_pred = (y_pred_prob > 0.5).astype(int).flatten()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.86      0.88        29
#            1       0.88      0.91      0.89        32
#
#     accuracy                           0.89        61
#    macro avg       0.89      0.88      0.88        61
# weighted avg       0.89      0.89      0.89        61

# %%
model.save('heart_attack_model_v2.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
